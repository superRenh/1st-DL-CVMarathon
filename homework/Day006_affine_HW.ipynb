# %% [markdown]
# # 作業
#
# 練習以旋轉變換 + 平移變換來實現仿射變換
# > 旋轉 45 度 + 縮放 0.5 倍 + 平移 (x+100, y-50)

# %%
import cv2
import time
import numpy as np
from PIL import Image

img = cv2.imread('data/lena.png')

# %% [markdown]
# ## Affine Transformation - Case 1: rotation 45 > scale 0..5 > shift (x+100, y-50)

# %%
# rotation 45 + rescale 0.5 
# cv2.getRotationMatrix2D(center, angel, scale)
rows, cols = img.shape[:2]
M_rot = cv2.getRotationMatrix2D((cols//2, rows//2), 45, 0.5)
print("M_rot", M_rot)
img_rot = cv2.warpAffine(img, M_rot, (cols, rows))

#shift x+100, y-50
M_shift = np.array([[1,0,100],[0,1,-50]], dtype=np.float32)
print("M_shift", M_shift)
img_shift = cv2.warpAffine(img_rot,M_shift,(cols, rows))
img_show_affine = np.hstack((img,img_rot,img_shift))
Image.fromarray(img_show_affine[:,:,::-1])
# Out:
# M_rot [[  0.35355339   0.35355339  74.98066402]
#  [ -0.35355339   0.35355339 256.        ]]
# M_shift [[  1.   0. 100.]
#  [  0.   1. -50.]]
# <PIL.Image.Image image mode=RGB size=1536x512 at 0x12E4ECC50>

# %% [markdown]
# ## Affine Transformation - Case 2: any three point

# %%
# 給定兩兩一對，共三對的點
# 這邊我們先用手動設定三對點，一般情況下會有點的資料或是透過介面手動標記三個點
rows, cols = img.shape[:2]
pt1 = np.array([[50,50], [300,100], [200,300]], dtype=np.float32)
pt2 = np.array([[80,80], [330,150], [300,300]], dtype=np.float32)

# 取得 affine 矩陣並做 affine 操作
M_affine = cv2.getAffineTransform(pt1, pt2)
img_affine = cv2.warpAffine(img,M_affine, (cols, rows))

# 在圖片上標記點
img_copy = img.copy()
for idx, pts in enumerate(pt1):
    pts = tuple(map(int, pts))
    cv2.circle(img_copy, pts, 3, (0, 255, 0), -1)
    cv2.putText(img_copy, str(idx), (pts[0]+5, pts[1]+5), cv2.FONT_HERSHEY_COMPLEX, 1, (0, 255, 0), 1)

for idx, pts in enumerate(pt2):
    pts = tuple(map(int, pts))
    cv2.circle(img_affine, pts, 3, (0, 255, 0), -1)
    cv2.putText(img_affine, str(idx), (pts[0]+5, pts[1]+5), cv2.FONT_HERSHEY_COMPLEX, 1, (0, 255, 0), 1)

# 組合 + 顯示圖片
# img_show_affine = np.hstack((img_copy, img_affine))
# while True:
#     cv2.imshow('affine transformation', img_show_affine)
#     k = cv2.waitKey(0)
#     if k == 27:
#         cv2.destroyAllWindows()
#         break

Img_show_affine = np.hstack((img_copy, img_affine))
Image.fromarray(Img_show_affine[:,:,::-1])
# Out:
# <PIL.Image.Image image mode=RGB size=1024x512 at 0x12CBB9F28>
