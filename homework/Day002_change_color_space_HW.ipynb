# %% [markdown]
# # 作業
# 使用 Lena
#
# 改變圖片的 color space (HLS, LAB) 並呈現

# %%
import cv2
import matplotlib.pyplot as plt
from PIL import Image
img = cv2.imread("./data/lena.png")
plt.imshow(img[:,:,::-1])
plt.show()

# %%
def Imagefarrayshow(array):
    return Image.fromarray(array)

# %%
cv2.imshow("HLS",cv2.cvtColor(img,cv2.COLOR_BGR2HLS))

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img_hls = cv2.cvtColor(img, cv2.COLOR_BGR2HLS)
Imagefarrayshow(img_hls)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x12CF76278>

# %%
img_lab = cv2.cvtColor(img, cv2.COLOR_BGR2LAB)
Imagefarrayshow(img_lab)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x12CF76DD8>

# %%
img_hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
Imagefarrayshow(img_hsv)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x12CF76E48>
